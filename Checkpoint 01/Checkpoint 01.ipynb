# %% [markdown]
# # **Checkpoint 01 - Modelagem de Dados e Aprendizagem de Máquina**
#
# ## **Objetivo**
# Avaliar conceitos sobre Modelagem de dados e Aprendizado de Máquina (ML) adquiridos no curso.
#
# ## **Descrição do Desafio**
# Você foi contratado por uma empresa inovadora do segmento imobiliário e foi incubido da tarefa de responder uma pergunta, que a princípio parece simples: **Quanto vale um imóvel de 72m2, com 2 quartos, 1 vaga, reformado no Centro?**
#
# ### **Orientações**
# Para responder a essa pergunta, você deve utilizar o dataset da empresa, que está representado no arquivo **aptos.csv**, e seguir o roteiro proposto neste desafio.

# %% [markdown]
# ## **Exploração de Dados - 2 pontos**
#
# 1 - Carregue o dataset e faça a inspeção nas 15 primeiras linhas para identificação dos atributos. (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 2 - Quantos dados existem nesse dataset? (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 3 - Qual a quantidade de atributos? Apresente uma breve descrição do significado de cada atributo. (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 4 - Cite dois cenários em que a correlação dos dados apresentados possa ajudar a responder a pergunta do desafio. (0,5)

# %% [markdown]
# Sua resposta:
#
# cenário 1:
#
# cenário 2:

# %% [markdown]
# ## **Analise descritiva dos dados - 2 pontos**
#
# 5 - Faça uma análise exploratória dos dados, utilizando gráficos e tabelas para realizar correlações entre os atributos e que permitam validar os cenários propostos.

# %% [markdown]
# Para o cenário 1: (1,0)

# %%
#Sua resposta aqui

# %% [markdown]
# Para o cenário 2: (1,0)

# %%
#Sua resposta aqui

# %% [markdown]
# ## **Desenvolvimento do Modelo - 2 pontos**
#
# 6 - O conjunto de dados indica a aplicação de qual modelo de aprendizagem de máquina para responder a pergunta do desafio? Por quê? (1,0)

# %% [markdown]
# Resposta:

# %% [markdown]
# 7 - Qual a técnica sugerida para este projeto? Por quê? (1,0)

# %% [markdown]
# Resposta:

# %% [markdown]
# Com base nas suas respostas, agora escolha dois algortimos para implementar e comparar a performance de cada um deles ao final do desafio.

# %% [markdown]
# Resposta:
#
# Algoritmo 1:
#
# Algoritmo 2:

# %% [markdown]
# ## **Treinamento e teste do Modelo - 3 pontos**
#
# 8 - Crie um subset dos dados com apenas os atributos que serão utilizados para o treinamento e para o teste do modelo. Divida este subset em treino e teste. (1,0)

# %%
#Sua resposta aqui

# %% [markdown]
# 9 - Faça o treinamento e teste dos 2 algoritmos escolhidos. Utilize uma métrica (ex. R2-score, RMSE e MAE...) para avaliar a performance dos modelos.

# %% [markdown]
# 9.1 - Algoritmo 1: (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 9.2 - Algoritmo 2:  (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 9.3 - Qual dos algortimos obteve melhor resultado? Por quê? (1,0)

# %% [markdown]
# Resposta:

# %% [markdown]
# ## **Modelo de Produção: Teste com novos dados - 1 ponto**
#
# 10 - Use o seu modelo treinado para responder a pergunta do desafio:

# %%
#Sua resposta aqui
