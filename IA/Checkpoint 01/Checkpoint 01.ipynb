# %% [markdown]
# # **Checkpoint 01 - Modelagem de Dados e Aprendizagem de Máquina**
#
# ## **Objetivo**
# Avaliar conceitos sobre Modelagem de dados e Aprendizado de Máquina (ML) adquiridos no curso.
#
# ## **Descrição do Desafio**
# Você foi contratado por uma empresa que desenvolveu uma plataforma de compra e venda de carros usados. O funcionamento é bem simples, os usuários cadastram o carro que querem vender e esperam que outro usuário os compre, a empresa então fica com uma parte do valor de venda. Seu papel é desenvolver um modelo que possa determinar qual o melhor preço de venda para um carro usado.
#
# Para nortear o desenvolvimento, você precisa de um ponto de partida e determinou uma pergunta chave: **Qual o preço de venda de um veículo Volkswagen Sedan 2.0 a gasolina, ano 2005, com cerca de 172095 km rodados?**
#
# Ao final do projeto, você deve enviar seu modelo treinado e um relatório em vídeo explicando como ele foi construído e avaliado. A empresa irá avaliar seu trabalho com base na precisão do modelo e na qualidade do relatório apresentado. Boa sorte!
#
# ## **Orientações**
# Para responder a essa pergunta, você deve utilizar o dataset da empresa, que está representado no arquivo **carros.csv**, e seguir o roteiro proposto neste desafio.

# %% [markdown]
# ## **Critério de avaliação**
# > Cada item do roteiro abaixo vale 1 ponto, totalizando 9 pontos;
#
# > O relatório em video vale 1 ponto;
#
# A entrega dos itens do roteiro e do video totalizam 10 pontos.

# %% [markdown]
# ## **Roteiro de Desenvolvimento**

# %% [markdown]
# 1 - Carregue o dataset e faça a inspeção nas 15 primeiras linhas para identificação dos atributos. Quantos dados existem nesse dataset? Qual a quantidade de atributos? Existem valores faltantes? De que tipo são os dados? (1,0)

# %%
#Sua resposta aqui

# Dica: pandas.read_csv

# %% [markdown]
# 2 - Note que os dataset está no sistema americano. Converta os dados para o sistema métrico e altere o cabeçalho de forma que os dados façam sentido. (1,0)
#
# Obs: Os dados de distância percorrida estão em Milhas/1000, ou seja, você precisa multiplicar por 1000 para obter o valor absoluto e depois tranformar milhas em km.

# %%
#Sua resposta aqui

# %% [markdown]
# 3 - Faça uma análise exploratória dos dados, utilizando gráficos e tabelas para realizar correlações entre os atributos e que permitam criar um cenário de correlação entre eles. (1,0)

# %%
#Sua resposta aqui

# %% [markdown]
# 4 - O conjunto de dados indica a aplicação de qual modelo de aprendizagem de máquina para responder a pergunta do desafio, Supervisionado, Não-Supervisionado ou Por Reforço? Por quê? (1,0)

# %% [markdown]
# Resposta:

# %% [markdown]
# 5 - Qual a técnica sugerida para este projeto, Classificação ou Regressão? Por quê? Com base nas suas respostas, agora escolha dois algortimos (Regressão Linear, Regressão Polinomial, Nayve-bayes, KNN, etc) para implementar e comparar a performance de cada um deles ao final do desafio.(1,0)

# %% [markdown]
# Resposta:

# %% [markdown]
# Algoritmo 1:
#
# Algoritmo 2:

# %% [markdown]
# 6 - Crie um subset com os dados que serão utilizados no modelo. Divida este subset em treino e teste. (1,0)

# %%
#Sua resposta aqui

#Dica: train_test_split()

# %% [markdown]
# 7 - Faça o treinamento e teste dos 2 algoritmos escolhidos. Utilize uma métrica (ex. R2-score, RMSE e MAE...) para avaliar a performance dos modelos.

# %% [markdown]
# 7.1 - Algoritmo 1: (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 7.2 - Algoritmo 2:  (0,5)

# %%
#Sua resposta aqui

# %% [markdown]
# 8 - Qual dos algortimos obteve melhor resultado? Por quê? (1,0)

# %% [markdown]
# Resposta:

# %% [markdown]
# 9 - Use o seu modelo treinado para responder a pergunta do desafio: **Qual o preço de venda de um veículo Volkswagen Sedan 2.0 a gasolina, ano 2005, com cerca de 172095 km rodados?** (1,0)

# %%
#Sua resposta aqui

# %% [markdown]
# 10 - Coloque aqui o link para o seu video explicativo (1,0)

# %% [markdown]
# Sua resposta aqui:
